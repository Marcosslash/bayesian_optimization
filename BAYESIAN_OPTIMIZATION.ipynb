# %% [markdown]
# # $ \text{Bayesian Optimization for Recommender System}$
#
# ### $\text{Bruno Giovanni Galuzzi (University of Milano-Bicocca, 20125 Milan, MI, Italy)}$

# %% [markdown]
# #### Springer Nature Switzerland AG 2020
# #### H. A. Le Thi et al. (Eds.): WCGO 2019, AISC 991, pp. 751–760, 2020.
# #### https://doi.org/10.1007/978-3-030-21803-4_75}

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import cross_validate

# %% [markdown]
# ### This dataset consists of 100.000 ratings (1–5) from 943 users on 1682 movies; thus, the rating matrix consists of 943 rows and 1682 columns, with around 100.000 known entries.

# %%
data = Dataset.load_builtin('ml-100k')

# %% [markdown]
# ### We defined the search space of possible configurations, $\Theta$ by setting the following ranges: number of latent factors $K$ in {10, 50}, both learning rate $\eta$ and regularization term $\lambda$ in [0.001, 0.1].

# %%
from skopt.space import Real, Integer
from skopt.utils import use_named_args

# The list of hyper-parameters we want to optimize. For each one we define the bounds,
# the corresponding scikit-learn parameter name, as well as how to sample values
# from that dimension (`'log-uniform'` for the learning rate)

space  = [
            Integer(10,50, name='n_factors'),
          
            Real(0.001, 0.1,"log-uniform", name='lr_all'),
          
            Real(0.001, 0.1,"log-uniform", name='reg_all') 
]


# this decorator allows your objective function to receive a the parameters as
# keyword arguments. This is particularly convenient when you want to set scikit-learn
# estimator parameters

@use_named_args(space)
def objective(**params):
    algo = SVD(**params)
    result = cross_validate(algo, data, measures=['RMSE'], cv=5, verbose=True,n_jobs=-1)
    
    return np.around(np.mean(result['test_rmse']), decimals=4)

# %% [markdown]
# ### $\text{Function used to minimize over the gaussian prior: "EI" for negative expected improvement. }$

# %%
from skopt import gp_minimize

res_gp = gp_minimize(objective, 
                     space, 
                     n_calls=50,
                     acq_func='EI',
                     base_estimator=None,
                     verbose=True,
                     n_jobs=-1)


print("Best score=%.4f" % res_gp.fun)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0329  1.0364  1.0412  1.0363  1.0465  1.0387  0.0047
# Fit time          1.85    2.30    1.93    2.31    1.93    2.06    0.20
# Test time         0.14    0.12    0.14    0.19    0.14    0.15    0.02
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 8.4541
# Function value obtained: 1.0387
# Current minimum: 1.0387
# Iteration No: 2 started. Evaluating function at random point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0859  1.0850  1.0961  1.0999  1.0952  1.0924  0.0059
# Fit time          1.79    1.77    2.00    1.80    2.13    1.90    0.14
# Test time         0.13    0.13    0.13    0.16    0.36    0.18    0.09
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 10.0467
# Function value obtained: 1.0924
# Current minimum: 1.0387
# Iteration No: 3 started. Evaluating function at random point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9561  0.9532  0.9610  0.9526  0.9493  0.9544  0.0039
# Fit time          1.17    1.12    1.23    1.37    1.18    1.21    0.08
# Test time         0.13    0.16    0.13    0.17    0.14    0.14    0.02
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 7.4630
# Function value obtained: 0.9544
# Current minimum: 0.9544
# Iteration No: 4 started. Evaluating function at random point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9461  0.9474  0.9436  0.9462  0.9411  0.9449  0.0023
# Fit time          1.82    1.68    1.97    1.58    1.50    1.71    0.17
# Test time         0.13    0.15    0.17    0.13    0.12    0.14    0.02
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 7.9990
# Function value obtained: 0.9449
# Current minimum: 0.9449
# Iteration No: 5 started. Evaluating function at random point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9342  0.9366  0.9446  0.9440  0.9354  0.9390  0.0044
# Fit time          2.11    2.49    2.13    2.61    2.42    2.35    0.20
# Test time         0.14    0.15    0.13    0.15    0.36    0.19    0.09
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 8.8462
# Function value obtained: 0.9390
# Current minimum: 0.9390
# Iteration No: 6 started. Evaluating function at random point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9371  0.9348  0.9413  0.9351  0.9507  0.9398  0.0060
# Fit time          1.26    1.51    1.22    1.23    1.34    1.31    0.11
# Test time         0.13    0.36    0.14    0.13    0.12    0.18    0.09
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 8.9358
# Function value obtained: 0.9398
# Current minimum: 0.9390
# Iteration No: 7 started. Evaluating function at random point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1374  1.1347  1.1321  1.1367  1.1329  1.1348  0.0020
# Fit time          1.59    1.87    1.86    14.50   1.60    4.29    5.11
# Test time         0.14    0.13    0.15    0.36    0.12    0.18    0.09
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 20.6514
# Function value obtained: 1.1348
# Current minimum: 0.9390
# Iteration No: 8 started. Evaluating function at random point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1471  1.1461  1.1509  1.1566  1.1633  1.1528  0.0064
# Fit time          1.44    1.49    1.46    21.64   1.57    5.52    8.06
# Test time         0.13    0.13    0.13    2.04    0.13    0.51    0.76
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 29.2663
# Function value obtained: 1.1528
# Current minimum: 0.9390
# Iteration No: 9 started. Evaluating function at random point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9562  0.9633  0.9585  0.9573  0.9392  0.9549  0.0082
# Fit time          1.37    1.33    1.69    1.36    1.56    1.46    0.14
# Test time         0.13    0.12    0.16    0.13    0.14    0.14    0.01
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 8.3967
# Function value obtained: 0.9549
# Current minimum: 0.9390
# Iteration No: 10 started. Evaluating function at random point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9737  0.9624  0.9768  0.9688  0.9714  0.9706  0.0049
# Fit time          1.14    1.45    1.10    1.31    1.26    1.25    0.13
# Test time         0.13    0.37    0.13    0.36    0.15    0.23    0.11
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 8.0859
# Function value obtained: 0.9706
# Current minimum: 0.9390
# Iteration No: 11 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9175  0.9257  0.9230  0.9251  0.9279  0.9239  0.0035
# Fit time          1.05    1.28    1.12    1.40    1.23    1.22    0.12
# Test time         0.12    0.30    0.14    0.14    0.38    0.22    0.10
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 8.4285
# Function value obtained: 0.9239
# Current minimum: 0.9239
# Iteration No: 12 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9540  0.9542  0.9613  0.9628  0.9622  0.9589  0.0040
# Fit time          1.17    1.19    1.32    1.14    1.04    1.17    0.09
# Test time         0.13    0.13    0.19    0.13    0.12    0.14    0.02
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 7.8364
# Function value obtained: 0.9589
# Current minimum: 0.9239
# Iteration No: 13 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9423  0.9370  0.9405  0.9369  0.9319  0.9377  0.0036
# Fit time          2.10    2.40    2.21    2.57    2.12    2.28    0.18
# Test time         0.14    0.13    0.14    0.16    0.15    0.14    0.01
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 8.3572
# Function value obtained: 0.9377
# Current minimum: 0.9239
# Iteration No: 14 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9703  0.9566  0.9619  0.9549  0.9601  0.9608  0.0054
# Fit time          2.04    2.36    2.02    2.12    2.16    2.14    0.12
# Test time         0.15    0.20    0.14    0.13    0.14    0.15    0.02
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 9.0962
# Function value obtained: 0.9608
# Current minimum: 0.9239
# Iteration No: 15 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0918  1.0878  1.0782  1.0949  1.0969  1.0899  0.0066
# Fit time          18.59   2.06    2.34    2.11    2.39    5.50    6.55
# Test time         0.14    0.13    0.15    0.13    0.17    0.15    0.02
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 21.1714
# Function value obtained: 1.0899
# Current minimum: 0.9239
# Iteration No: 16 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9318  0.9206  0.9310  0.9203  0.9235  0.9255  0.0050
# Fit time          1.01    1.17    1.02    1.01    1.13    1.07    0.07
# Test time         0.14    0.16    0.14    0.13    0.13    0.14    0.01
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 12.6573
# Function value obtained: 0.9255
# Current minimum: 0.9239
# Iteration No: 17 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9194  0.9193  0.9113  0.9161  0.9194  0.9171  0.0032
# Fit time          1.32    1.20    1.19    1.34    1.35    1.28    0.07
# Test time         0.13    0.13    0.14    0.13    0.15    0.14    0.01
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 13.6368
# Function value obtained: 0.9171
# Current minimum: 0.9171
# Iteration No: 18 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9464  0.9413  0.9397  0.9378  0.9457  0.9422  0.0034
# Fit time          2.25    2.96    2.99    2.61    2.40    2.64    0.30
# Test time         0.14    0.16    0.15    0.15    0.15    0.15    0.01
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 9.5758
# Function value obtained: 0.9422
# Current minimum: 0.9171
# Iteration No: 19 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9603  0.9590  0.9624  0.9601  0.9546  0.9593  0.0026
# Fit time          1.53    1.32    1.69    1.31    1.32    1.43    0.15
# Test time         0.15    0.14    0.16    0.14    0.15    0.15    0.01
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 8.0193
# Function value obtained: 0.9593
# Current minimum: 0.9171
# Iteration No: 20 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9653  0.9648  0.9633  0.9634  0.9625  0.9639  0.0010
# Fit time          1.45    1.44    1.59    1.83    1.62    1.58    0.14
# Test time         0.14    0.15    0.14    0.15    0.17    0.15    0.01
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 11.1517
# Function value obtained: 0.9639
# Current minimum: 0.9171
# Iteration No: 21 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9431  0.9475  0.9500  0.9535  0.9439  0.9476  0.0039
# Fit time          2.58    1.29    1.37    1.50    1.18    1.58    0.51
# Test time         0.16    0.13    0.15    0.16    0.13    0.15    0.01
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 8.5580
# Function value obtained: 0.9476
# Current minimum: 0.9171
# Iteration No: 22 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9295  0.9262  0.9235  0.9258  0.9172  0.9244  0.0041
# Fit time          1.99    2.31    2.19    2.48    2.60    2.32    0.21
# Test time         0.14    0.17    0.15    0.14    0.13    0.14    0.01
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 12.9610
# Function value obtained: 0.9244
# Current minimum: 0.9171
# Iteration No: 23 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9258  0.9187  0.9264  0.9203  0.9268  0.9236  0.0034
# Fit time          1.08    1.04    1.13    1.21    1.02    1.09    0.07
# Test time         0.14    0.16    0.20    0.16    0.13    0.16    0.03
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 8.1892
# Function value obtained: 0.9236
# Current minimum: 0.9171
# Iteration No: 24 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9442  0.9485  0.9460  0.9482  0.9433  0.9460  0.0021
# Fit time          1.14    1.41    1.07    1.34    1.07    1.21    0.14
# Test time         0.15    0.36    0.13    0.36    0.14    0.23    0.11
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 8.9028
# Function value obtained: 0.9460
# Current minimum: 0.9171
# Iteration No: 25 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9438  0.9337  0.9347  0.9346  0.9305  0.9355  0.0044
# Fit time          1.43    1.18    1.39    1.17    1.09    1.25    0.13
# Test time         0.37    0.13    0.36    0.14    0.13    0.23    0.11
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 10.9746
# Function value obtained: 0.9355
# Current minimum: 0.9171
# Iteration No: 26 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9539  0.9674  0.9467  0.9697  0.9611  0.9598  0.0086
# Fit time          1.30    1.29    1.55    1.28    1.28    1.34    0.11
# Test time         0.15    0.13    0.36    0.14    0.12    0.18    0.09
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 9.7524
# Function value obtained: 0.9598
# Current minimum: 0.9171
# Iteration No: 27 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9341  0.9434  0.9352  0.9386  0.9455  0.9394  0.0045
# Fit time          1.51    1.31    1.39    20.81   1.30    5.26    7.78
# Test time         0.36    0.14    0.13    2.38    0.14    0.63    0.88
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 28.9136
# Function value obtained: 0.9394
# Current minimum: 0.9171
# Iteration No: 28 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9163  0.9171  0.9155  0.9128  0.9222  0.9168  0.0031
# Fit time          1.24    1.30    1.32    18.77   1.27    4.78    6.99
# Test time         0.14    0.15    0.16    2.45    0.14    0.61    0.92
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 27.2795
# Function value obtained: 0.9168
# Current minimum: 0.9168
# Iteration No: 29 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9352  0.9255  0.9313  0.9332  0.9405  0.9331  0.0049
# Fit time          1.73    28.77   1.63    1.89    1.65    7.14    10.82
# Test time         0.14    2.22    0.14    0.16    0.14    0.56    0.83
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 34.9421
# Function value obtained: 0.9331
# Current minimum: 0.9168
# Iteration No: 30 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9088  0.9134  0.9144  0.9178  0.9160  0.9141  0.0030
# Fit time          2.08    2.28    2.20    2.54    2.03    2.22    0.18
# Test time         0.14    0.13    0.13    0.35    0.13    0.18    0.09
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 8.4326
# Function value obtained: 0.9141
# Current minimum: 0.9141
# Iteration No: 31 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9537  0.9543  0.9587  0.9636  0.9710  0.9603  0.0064
# Fit time          2.17    2.41    2.48    2.47    2.15    2.34    0.15
# Test time         0.15    0.16    0.15    0.15    0.14    0.15    0.01
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 11.4699
# Function value obtained: 0.9603
# Current minimum: 0.9141
# Iteration No: 32 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9422  0.9429  0.9470  0.9330  0.9490  0.9428  0.0055
# Fit time          1.88    2.17    1.85    1.81    1.79    1.90    0.14
# Test time         0.14    0.17    0.14    0.14    0.13    0.14    0.01
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 14.0860
# Function value obtained: 0.9428
# Current minimum: 0.9141
# Iteration No: 33 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9285  0.9218  0.9226  0.9158  0.9241  0.9225  0.0041
# Fit time          1.99    1.96    6.84    1.84    2.04    2.93    1.95
# Test time         0.14    0.13    0.12    0.13    0.13    0.13    0.00
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 11.9374
# Function value obtained: 0.9225
# Current minimum: 0.9141
# Iteration No: 34 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9573  0.9603  0.9593  0.9519  0.9567  0.9571  0.0029
# Fit time          2.16    2.36    2.45    2.54    1.97    2.30    0.21
# Test time         0.14    0.13    0.14    0.34    0.12    0.18    0.08
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 11.3616
# Function value obtained: 0.9571
# Current minimum: 0.9141
# Iteration No: 35 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9321  0.9390  0.9371  0.9371  0.9395  0.9370  0.0026
# Fit time          1.47    1.34    1.17    1.17    1.13    1.26    0.13
# Test time         0.18    0.29    0.16    0.15    0.13    0.18    0.06
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 9.8118
# Function value obtained: 0.9370
# Current minimum: 0.9141
# Iteration No: 36 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9186  0.9247  0.9190  0.9158  0.9182  0.9193  0.0029
# Fit time          2.13    2.24    2.32    2.60    2.31    2.32    0.16
# Test time         0.19    0.15    0.14    0.17    0.14    0.16    0.02
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 9.7003
# Function value obtained: 0.9193
# Current minimum: 0.9141
# Iteration No: 37 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9542  0.9434  0.9478  0.9510  0.9548  0.9502  0.0042
# Fit time          2.00    1.91    2.10    1.91    1.81    1.95    0.10
# Test time         0.14    0.14    0.14    0.14    0.15    0.14    0.00
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 8.6872
# Function value obtained: 0.9502
# Current minimum: 0.9141
# Iteration No: 38 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9101  0.9221  0.9220  0.9123  0.9167  0.9166  0.0049
# Fit time          2.03    2.11    1.86    1.89    1.91    1.96    0.10
# Test time         0.14    0.20    0.14    0.14    0.16    0.16    0.02
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 9.0201
# Function value obtained: 0.9166
# Current minimum: 0.9141
# Iteration No: 39 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9187  0.9114  0.9125  0.9181  0.9104  0.9142  0.0035
# Fit time          2.00    1.94    2.09    2.04    1.97    2.01    0.05
# Test time         0.15    0.15    0.18    0.16    0.16    0.16    0.01
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 9.2450
# Function value obtained: 0.9142
# Current minimum: 0.9141
# Iteration No: 40 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9247  0.9255  0.9287  0.9228  0.9210  0.9246  0.0026
# Fit time          2.23    2.11    32.05   2.41    2.27    8.21    11.92
# Test time         0.14    0.15    2.25    0.15    0.14    0.57    0.84
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 39.2971
# Function value obtained: 0.9246
# Current minimum: 0.9141
# Iteration No: 41 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9311  0.9216  0.9275  0.9380  0.9342  0.9305  0.0056
# Fit time          2.03    2.74    2.45    2.09    2.25    2.31    0.26
# Test time         0.15    0.17    0.16    0.14    0.14    0.15    0.01
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 9.1445
# Function value obtained: 0.9305
# Current minimum: 0.9141
# Iteration No: 42 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9176  0.9109  0.9150  0.9045  0.9167  0.9129  0.0048
# Fit time          2.19    2.23    2.23    2.67    2.16    2.30    0.19
# Test time         0.14    0.15    0.15    0.17    0.16    0.15    0.01
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 9.8353
# Function value obtained: 0.9129
# Current minimum: 0.9129
# Iteration No: 43 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9189  0.9169  0.9210  0.9179  0.9115  0.9172  0.0032
# Fit time          2.06    2.18    2.13    2.03    2.16    2.11    0.06
# Test time         0.13    0.13    0.16    0.13    0.12    0.13    0.01
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 27.3693
# Function value obtained: 0.9172
# Current minimum: 0.9129
# Iteration No: 44 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9558  0.9456  0.9424  0.9512  0.9541  0.9498  0.0051
# Fit time          1.86    1.85    30.38   1.73    1.71    7.51    11.44
# Test time         0.14    0.14    2.12    0.14    0.13    0.53    0.79
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 37.7226
# Function value obtained: 0.9498
# Current minimum: 0.9129
# Iteration No: 45 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9144  0.9152  0.9215  0.9082  0.9154  0.9150  0.0042
# Fit time          2.10    2.50    2.03    2.25    2.06    2.19    0.17
# Test time         0.15    0.37    0.14    0.13    0.13    0.19    0.09
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 8.7535
# Function value obtained: 0.9150
# Current minimum: 0.9129
# Iteration No: 46 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9223  0.9069  0.9154  0.9059  0.9167  0.9134  0.0062
# Fit time          2.35    2.03    2.01    2.04    1.94    2.07    0.14
# Test time         0.13    0.13    0.16    0.13    0.13    0.14    0.01
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 9.5854
# Function value obtained: 0.9134
# Current minimum: 0.9129
# Iteration No: 47 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9546  0.9607  0.9577  0.9526  0.9506  0.9552  0.0036
# Fit time          2.14    2.12    2.56    2.28    2.08    2.24    0.17
# Test time         0.14    0.14    0.14    0.14    0.14    0.14    0.00
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 8.7330
# Function value obtained: 0.9552
# Current minimum: 0.9129
# Iteration No: 48 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9391  0.9491  0.9413  0.9352  0.9427  0.9415  0.0046
# Fit time          2.12    2.32    2.61    2.45    2.05    2.31    0.20
# Test time         0.15    0.14    0.38    0.16    0.13    0.19    0.10
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 8.5953
# Function value obtained: 0.9415
# Current minimum: 0.9129
# Iteration No: 49 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9477  0.9439  0.9453  0.9402  0.9433  0.9441  0.0025
# Fit time          2.64    2.17    2.12    2.38    2.03    2.27    0.22
# Test time         0.38    0.17    0.14    0.13    0.13    0.19    0.10
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 8.4440
# Function value obtained: 0.9441
# Current minimum: 0.9129
# Iteration No: 50 started. Searching for the next optimal point.
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9539  0.9597  0.9593  0.9562  0.9631  0.9585  0.0032
# Fit time          1.10    1.08    1.09    1.20    1.27    1.15    0.08
# Test time         0.14    0.13    0.15    0.14    0.17    0.15    0.01
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 7.9521
# Function value obtained: 0.9585
# Current minimum: 0.9129
# Best score=0.9129

# %%
print("Best score (rmse) = %.4f" % res_gp.fun)

print("""Best hyper parameters:
- n_factors = %d
- learning_rate= %.6f
- regularization_rate = %.6f

""" % (res_gp.x[0], res_gp.x[1],res_gp.x[2]))
# Out:
# Best score (rmse) = 0.9129
# Best hyper parameters:
# - n_factors = 50
# - learning_rate= 0.017731
# - regularization_rate = 0.098504

# %% [markdown]
# ### Plot one or several convergence traces.

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
from matplotlib.ticker import LogLocator
from matplotlib.ticker import MaxNLocator

from scipy.optimize import OptimizeResult
def plot_convergence1(*args, **kwargs):
    """Plot one or several convergence traces.

    Parameters
    ----------
    * `args[i]` [`OptimizeResult`, list of `OptimizeResult`, or tuple]:
        The result(s) for which to plot the convergence trace.

        - if `OptimizeResult`, then draw the corresponding single trace;
        - if list of `OptimizeResult`, then draw the corresponding convergence
          traces in transparency, along with the average convergence trace;
        - if tuple, then `args[i][0]` should be a string label and `args[i][1]`
          an `OptimizeResult` or a list of `OptimizeResult`.

    * `ax` [`Axes`, optional]:
        The matplotlib axes on which to draw the plot, or `None` to create
        a new one.

    * `true_minimum` [float, optional]:
        The true minimum value of the function, if known.

    * `yscale` [None or string, optional]:
        The scale for the y-axis.

    Returns
    -------
    * `ax`: [`Axes`]:
        The matplotlib axes.
    """
    # <3 legacy python
    ax = kwargs.get("ax", None)
    true_minimum = kwargs.get("true_minimum", None)
    yscale = kwargs.get("yscale", None)

    if ax is None:
        ax = plt.gca()

    ax.set_title("Convergence plot")
    ax.set_xlabel("Number of calls $n$")
    ax.set_ylabel(r"$\min$ RMSE after $n$ calls")
#     ax.grid()

    if yscale is not None:
        ax.set_yscale(yscale)

    colors = cm.viridis(np.linspace(0.25, 1.0, len(args)))

    for results, color in zip(args, colors):
        if isinstance(results, tuple):
            name, results = results
        else:
            name = None

        if isinstance(results, OptimizeResult):
            n_calls = len(results.x_iters)
            mins = [np.min(results.func_vals[:i])
                    for i in range(1, n_calls + 1)]
            ax.plot(range(1, n_calls + 1), mins, c=color,
                    marker=".", markersize=12, lw=2, label=name)

        elif isinstance(results, list):
            n_calls = len(results[0].x_iters)
            iterations = range(1, n_calls + 1)
            mins = [[np.min(r.func_vals[:i]) for i in iterations]
                    for r in results]

            for m in mins:
                ax.plot(iterations, m, c=color, alpha=0.2)

            ax.plot(iterations, np.mean(mins, axis=0), c=color,
                    marker=".", markersize=12, lw=2, label=name)

    if true_minimum:
        ax.axhline(true_minimum, linestyle="--",
                   color="r", lw=1,
                   label="True minimum")

    if true_minimum or name:
        ax.legend(loc="best")

    return ax

# %%
plot_convergence1(res_gp,true_minimum=0.9129)

# %% [markdown]
# ### Test hyperparameters as the mean of 5-fold cross-validation.
#
# ### True minimum should be $\approx 0.9129$

# %%
algo_1 = SVD(  
               n_factors=50,
               lr_all=0.017731,
               reg_all=0.098504
            )



cross_validate(algo_1, data, measures=['RMSE'], return_train_measures=True, cv=5, verbose=True,n_jobs=-1)
# Out:
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9125  0.9132  0.9163  0.9053  0.9158  0.9126  0.0039
# RMSE (trainset)   0.7451  0.7473  0.7434  0.7449  0.7430  0.7447  0.0015
# Fit time          2.45    14.28   2.41    2.14    2.22    4.70    4.79
# Test time         0.15    0.37    0.15    0.14    0.13    0.19    0.09
# {'test_rmse': array([0.91250978, 0.91322019, 0.91632901, 0.90532169, 0.91580417]),
#  'train_rmse': array([0.74512153, 0.74726468, 0.74337267, 0.74485185, 0.74300728]),
#  'fit_time': (2.447819471359253,
#   14.276379346847534,
#   2.4119374752044678,
#   2.141545295715332,
#   2.2218496799468994),
#  'test_time': (0.15401172637939453,
#   0.3665006160736084,
#   0.14890599250793457,
#   0.13584613800048828,
#   0.12658190727233887)}
